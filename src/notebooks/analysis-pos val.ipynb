# %%
import pandas as pd

# %%
data = pd.read_csv('../data/data/porttinari_labeled_final.csv')
data
# Out:
#      dialogue_id sentence_id  \
# 0      DOC000001     SENT003
# 1      DOC000001     SENT004
# 2      DOC000001     SENT005
# 3      DOC000001     SENT008
# 4      DOC000001     SENT010
# ...          ...         ...
# 4086   DOC004526     SENT006
# 4087   DOC004619     SENT008
# 4088   DOC004679     SENT030
# 4089   DOC004774     SENT007
# 4090   DOC004780     SENT007
#
#                                               sentences  \
# 0     Eu sei que tô lascado , todo dia tem um proces...
# 1     Eu não quero nem que Moro me absolva , eu só q...
# 2     Eles [ investigadores ] chegam a dizer : ' Ah ...
# 3     O ex-presidente disse ainda não ter " medo " d...
# 4     De acordo com aliados , Lula não gosta de disc...
# ...                                                 ...
# 4086  Desde a ruptura do modelo de industrialização ...
# 4087  Acho que é ... olha , nem consigo achar um adj...
# 4088  " Acho que me acostumei com o clima do bairro ...
# 4089  Ele já se movimenta há meses , contatando lide...
# 4090  A queda em a produtividade arrastou com si o P...
#
#                                     tipo dimensão multi  \
# 0                              General-purpose function
# 1                              General-purpose function
# 2                              General-purpose function
# 3                              General-purpose function
# 4                              General-purpose function
# ...                                                 ...
# 4086                           General-purpose function
# 4087  General-purpose function / Dimension-specific ...
# 4088                           General-purpose function
# 4089                           General-purpose function
# 4090                           General-purpose function
#
#                                          Dimensão multi         função multi  \
# 0                       Information-providing functions               inform
# 1                       Information-providing functions               inform
# 2                       Information-providing functions               inform
# 3                       Information-providing functions               inform
# 4                       Information-providing functions               inform
# ...                                                 ...                  ...
# 4086                    Information-providing functions               inform
# 4087  Information-providing functions /  Social obli...  inform / compliment
# 4088                    Information-providing functions               inform
# 4089                    Information-providing functions               inform
# 4090                    Information-providing functions               inform
#
#      revisado                  tipo dimensão  \
# 0         sim       General-purpose function
# 1         sim       General-purpose function
# 2         sim       General-purpose function
# 3         sim       General-purpose function
# 4         sim       General-purpose function
# ...       ...                            ...
# 4086      sim       General-purpose function
# 4087   duvida  Dimension-specific functions
# 4088      sim       General-purpose function
# 4089      sim       General-purpose function
# 4090      sim       General-purpose function
#
#                                      Dimensão        função  Unnamed: 10  \
# 0             Information-providing functions  disagreement          NaN
# 1             Information-providing functions        inform          NaN
# 2             Information-providing functions        inform          NaN
# 3             Information-providing functions        inform          NaN
# 4             Information-providing functions        inform          NaN
# ...                                       ...           ...          ...
# 4086          Information-providing functions        inform          NaN
# 4087  Social obligations management functions        inform          NaN
# 4088          Information-providing functions        inform          NaN
# 4089          Information-providing functions        inform          NaN
# 4090          Information-providing functions        inform          NaN
#
#      possivel tag dialogue_id.1  \
# 0             NaN     DOC000001
# 1             NaN     DOC000001
# 2             NaN     DOC000001
# 3             NaN     DOC000001
# 4             NaN     DOC000001
# ...           ...           ...
# 4086          NaN     DOC004526
# 4087   compliment     DOC004619
# 4088          NaN     DOC004679
# 4089          NaN     DOC004774
# 4090          NaN     DOC004780
#
#                                                  tokens  \
# 0     ['Eu', 'sei', 'que', 'tô', 'lascado', ',', 'to...
# 1     ['Eu', 'não', 'quero', 'nem', 'que', 'Moro', '...
# 2     ['Eles', '[', 'investigadores', ']', 'chegam',...
# 3     ['O', 'ex-presidente', 'disse', 'ainda', 'não'...
# 4     ['De', 'acordo', 'com', 'aliados', ',', 'Lula'...
# ...                                                 ...
# 4086  ['Desde', 'a', 'ruptura', 'do', 'de', 'o', 'mo...
# 4087  ['Acho', 'que', 'é', '...', 'olha', ',', 'nem'...
# 4088  ['"', 'Acho', 'que', 'me', 'acostumei', 'com',...
# 4089  ['Ele', 'já', 'se', 'movimenta', 'há', 'meses'...
# 4090  ['A', 'queda', 'em', 'a', 'produtividade', 'ar...
#
#                                                     pos
# 0     ['PRON', 'VERB', 'SCONJ', 'AUX', 'ADJ', 'PUNCT...
# 1     ['PRON', 'ADV', 'VERB', 'ADV', 'SCONJ', 'PROPN...
# 2     ['PRON', 'PUNCT', 'NOUN', 'PUNCT', 'VERB', 'AD...
# 3     ['DET', 'NOUN', 'VERB', 'ADV', 'ADV', 'VERB', ...
# 4     ['ADP', 'NOUN', 'ADP', 'NOUN', 'PUNCT', 'PROPN...
# ...                                                 ...
# 4086  ['ADP', 'DET', 'NOUN', '_', 'ADP', 'DET', 'NOU...
# 4087  ['VERB', 'SCONJ', 'AUX', 'PUNCT', 'VERB', 'PUN...
# 4088  ['PUNCT', 'VERB', 'SCONJ', 'PRON', 'VERB', 'AD...
# 4089  ['PRON', 'ADV', 'PRON', 'VERB', 'VERB', 'NOUN'...
# 4090  ['DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', ...
#
# [4091 rows x 15 columns]

# %%
data['função'].value_counts()
# Out:
# função
# inform                 3905
# question                 95
# instruct                 15
# suggest                  14
# disagreement             12
# answer                   12
# confirm                   7
# agreement                 7
# correction                5
# compliment                4
# sympathy expression       3
# request                   3
# thanking                  3
# disconfirm                3
# congratulations           1
# promise                   1
# apology                   1
# Name: count, dtype: int64

# %%
dimension={"information-providing functions":["inform", 
                                    "agreement", 
                                    "disagreement", 
                                    "confirm", 
                                    "disconfirm", "correction",
                                    "answer"],
"information-seeking functions": ["question"],
"directive functions": ["instruct", "suggest", "request"],
"commissive functions": ["promise"],
"social obligations management functions": ["compliment", "sympathy expression", "thanking", "congratulations", "apology"]
}

# %%
def map_function(func_value):
    for key, values in dimension.items():
        if func_value in values:
            return key
    return None  # Ou qualquer outro valor padrão para quando não houver correspondência

# Aplicar a função de mapeamento à coluna "função"
data['new_dimension'] = data['função'].map(map_function)

# %%
data['new_dimension'].value_counts()
# Out:
# new_dimension
# information-providing functions            3951
# information-seeking functions                95
# directive functions                          32
# social obligations management functions      12
# commissive functions                          1
# Name: count, dtype: int64

# %%
all_results = pd.read_csv(r'../data/outputs/results/results.csv').set_index('Unnamed: 0')
all_results.columns
# Out:
# Index(['precision', 'recall', 'f1-score', 'support', 'model_name', 'dataset',
#        'use_pos', 'use_context', 'use_trans', 'use_weights', 'batch_size',
#        'epoch', 'lr_rate', 'resample_perc', 'n_classes', 'timestamp_now'],
#       dtype='object')

# %%
import itertools
list_resample_perc = [0.1, 0.05, 0.01]
list_lr_rate = [5e-5, 1e-5, 5e-6]
list_pos = [True, False]
list_context = [True, False]
list_trans = [True, False]
list_use_weights = [True, False]

all_combinations = itertools.product(*[list_pos, list_context, list_trans, list_resample_perc, list_lr_rate, list_use_weights])


best_comb_results = []
for pos, con, trans, resample, lr_rate, use_weights in all_combinations:
    best_epoch = all_results[(all_results['model_name']=='main') & (all_results['use_pos']==pos) & (all_results['use_trans']==trans) 
            & (all_results['use_context']==con)  & (all_results['dataset']=='test') & (all_results['lr_rate']==	lr_rate) &
            (all_results['resample_perc']==resample) & (all_results['use_weights']==use_weights) & (all_results['dataset']=='test')].iloc[-1]['epoch']
    best_comb_results.append([pos, con, trans, resample, lr_rate, use_weights, best_epoch])

all_combinations = itertools.product(*[list_pos, list_context, list_trans])

df_best_comb_results = pd.DataFrame(best_comb_results, columns=["pos", "con", "trans", "resample", "lr_rate", "use_weights", "best_epoch"])
all_best = pd.DataFrame()
for pos, con, trans in all_combinations:
    df_all_best_comb = df_best_comb_results[(df_best_comb_results['pos']==pos) & (df_best_comb_results['con']==con) & (df_best_comb_results['trans']==trans)]

    best_results_comb = pd.DataFrame()
    for idx, row in df_all_best_comb.iterrows():
        best_results_comb = pd.concat([best_results_comb, all_results[(all_results['model_name']=='main') & (all_results['use_pos']==row["pos"]) & (all_results['use_trans']==row["trans"]) 
                & (all_results['use_context']==row["con"])  & (all_results['lr_rate']==row["lr_rate"]) &
                (all_results['resample_perc']==row['resample']) & (all_results['use_weights']==row["use_weights"]) & (all_results['dataset']=='val')
                & (all_results['epoch']==row['best_epoch'])]])
    best_params = best_results_comb.loc['macro avg'].sort_values(['f1-score'], ascending=False).iloc[0]
    all_best = pd.concat([
        all_best,  best_results_comb[(best_results_comb['model_name']=='main') & (best_results_comb['use_pos']==best_params["use_pos"]) & (best_results_comb['use_trans']==best_params["use_trans"]) 
                & (best_results_comb['use_context']==best_params["use_context"])  & (best_results_comb['lr_rate']==best_params["lr_rate"]) &
                (best_results_comb['resample_perc']==best_params['resample_perc']) & (best_results_comb['use_weights']==best_params["use_weights"]) & (best_results_comb['dataset']=='val')
                & (best_results_comb['epoch']==best_params['epoch'])]
    ])

# %%
all_best.loc['macro avg'].sort_values(['f1-score'], ascending=False)
# Out:
#             precision    recall  f1-score  support model_name dataset  \
# Unnamed: 0
# macro avg    0.583403  0.694340  0.609012    434.0       main     val
# macro avg    0.506730  0.654088  0.533477    434.0       main     val
# macro avg    0.498077  0.594340  0.529524    434.0       main     val
# macro avg    0.464691  0.589151  0.508638    434.0       main     val
# macro avg    0.459808  0.776415  0.487654    434.0       main     val
# macro avg    0.435916  0.497248  0.459369    434.0       main     val
# macro avg    0.306933  0.551038  0.345127    434.0       main     val
# macro avg    0.295830  0.483491  0.327807    434.0       main     val
#
#             use_pos  use_context  use_trans  use_weights  batch_size  epoch  \
# Unnamed: 0
# macro avg      True        False       True         True           4     13
# macro avg     False        False      False        False           4     13
# macro avg     False         True      False         True           4     11
# macro avg     False        False       True        False           4     19
# macro avg      True        False      False        False           4      5
# macro avg      True         True       True         True           4     12
# macro avg     False         True       True         True           4      6
# macro avg      True         True      False        False           4     12
#
#              lr_rate  resample_perc  n_classes        timestamp_now
# Unnamed: 0
# macro avg   0.000005           0.10          7  2024-06-22 21:44:45
# macro avg   0.000010           0.05          7  2024-06-24 20:23:58
# macro avg   0.000010           0.10          7  2024-06-24 02:38:58
# macro avg   0.000005           0.05          7  2024-06-24 15:02:06
# macro avg   0.000050           0.05          7  2024-06-23 12:24:40
# macro avg   0.000050           0.10          7  2024-06-21 13:51:25
# macro avg   0.000050           0.05          7  2024-06-23 20:15:22
# macro avg   0.000005           0.10          7  2024-06-22 10:51:56

# %%
#all_best.loc['macro avg'].sort_values(['f1-score'], ascending=False).to_csv("../data/outputs/results/best_params.csv", index=False)

# %%
best_test = pd.DataFrame()
for idx, row in all_best.loc['macro avg'].sort_values(['f1-score'], ascending=False).iterrows():
    epoch = all_results[(all_results['model_name']=='main') & (all_results['use_pos']==row["use_pos"]) & (all_results['use_trans']==row["use_trans"]) 
                & (all_results['use_context']==row["use_context"])  & (all_results['lr_rate']==row["lr_rate"]) &
                (all_results['resample_perc']==row['resample_perc']) & (all_results['use_weights']==row["use_weights"]) & (all_results['dataset']=='test')].iloc[-1]['epoch']
    
    test_results = all_results[(all_results['model_name']=='main') & (all_results['use_pos']==row["use_pos"]) & (all_results['use_trans']==row["use_trans"]) 
                & (all_results['use_context']==row["use_context"])  & (all_results['lr_rate']==row["lr_rate"]) &
                (all_results['resample_perc']==row['resample_perc']) & (all_results['use_weights']==row["use_weights"]) & (all_results['dataset']=='val')
                & (all_results['epoch']==epoch)][:10]

    if 'answer' in test_results.index:
        test_results.drop(index=['answer'], inplace=True)

        
    
    best_test = pd.concat([best_test, test_results])
best_test
# Out:
#               precision    recall  f1-score     support model_name dataset  \
# Unnamed: 0
# disagreement   1.000000  1.000000  1.000000    1.000000       main     val
# inform         0.992771  0.971698  0.982122  424.000000       main     val
# other          0.090909  0.500000  0.153846    2.000000       main     val
# question       0.833333  1.000000  0.909091    5.000000       main     val
# suggest        0.000000  0.000000  0.000000    2.000000       main     val
# ...                 ...       ...       ...         ...        ...     ...
# question       0.454545  1.000000  0.625000    5.000000       main     val
# suggest        0.000000  0.000000  0.000000    2.000000       main     val
# accuracy       0.910138  0.910138  0.910138    0.910138       main     val
# macro avg      0.295830  0.483491  0.327807  434.000000       main     val
# weighted avg   0.974867  0.910138  0.938943  434.000000       main     val
#
#               use_pos  use_context  use_trans  use_weights  batch_size  epoch  \
# Unnamed: 0
# disagreement     True        False       True         True           4     13
# inform           True        False       True         True           4     13
# other            True        False       True         True           4     13
# question         True        False       True         True           4     13
# suggest          True        False       True         True           4     13
# ...               ...          ...        ...          ...         ...    ...
# question         True         True      False        False           4     12
# suggest          True         True      False        False           4     12
# accuracy         True         True      False        False           4     12
# macro avg        True         True      False        False           4     12
# weighted avg     True         True      False        False           4     12
#
#                lr_rate  resample_perc  n_classes        timestamp_now
# Unnamed: 0
# disagreement  0.000005            0.1          7  2024-06-22 21:44:45
# inform        0.000005            0.1          7  2024-06-22 21:44:45
# other         0.000005            0.1          7  2024-06-22 21:44:45
# question      0.000005            0.1          7  2024-06-22 21:44:45
# suggest       0.000005            0.1          7  2024-06-22 21:44:45
# ...                ...            ...        ...                  ...
# question      0.000005            0.1          7  2024-06-22 10:51:56
# suggest       0.000005            0.1          7  2024-06-22 10:51:56
# accuracy      0.000005            0.1          7  2024-06-22 10:51:56
# macro avg     0.000005            0.1          7  2024-06-22 10:51:56
# weighted avg  0.000005            0.1          7  2024-06-22 10:51:56
#
# [64 rows x 16 columns]

# %%
best_test[(best_test['use_pos']==True) & (best_test['use_context']==False) & (best_test['use_trans']==True)]
# Out:
#               precision    recall  f1-score     support model_name dataset  \
# Unnamed: 0
# disagreement   1.000000  1.000000  1.000000    1.000000       main     val
# inform         0.992771  0.971698  0.982122  424.000000       main     val
# other          0.090909  0.500000  0.153846    2.000000       main     val
# question       0.833333  1.000000  0.909091    5.000000       main     val
# suggest        0.000000  0.000000  0.000000    2.000000       main     val
# accuracy       0.965438  0.965438  0.965438    0.965438       main     val
# macro avg      0.583403  0.694340  0.609012  434.000000       main     val
# weighted avg   0.982220  0.965438  0.972979  434.000000       main     val
#
#               use_pos  use_context  use_trans  use_weights  batch_size  epoch  \
# Unnamed: 0
# disagreement     True        False       True         True           4     13
# inform           True        False       True         True           4     13
# other            True        False       True         True           4     13
# question         True        False       True         True           4     13
# suggest          True        False       True         True           4     13
# accuracy         True        False       True         True           4     13
# macro avg        True        False       True         True           4     13
# weighted avg     True        False       True         True           4     13
#
#                lr_rate  resample_perc  n_classes        timestamp_now
# Unnamed: 0
# disagreement  0.000005            0.1          7  2024-06-22 21:44:45
# inform        0.000005            0.1          7  2024-06-22 21:44:45
# other         0.000005            0.1          7  2024-06-22 21:44:45
# question      0.000005            0.1          7  2024-06-22 21:44:45
# suggest       0.000005            0.1          7  2024-06-22 21:44:45
# accuracy      0.000005            0.1          7  2024-06-22 21:44:45
# macro avg     0.000005            0.1          7  2024-06-22 21:44:45
# weighted avg  0.000005            0.1          7  2024-06-22 21:44:45

# %%
best_test[(best_test['use_pos']==False) & (best_test['use_context']==False) & (best_test['use_trans']==False)]
# Out:
#               precision    recall  f1-score     support model_name dataset  \
# Unnamed: 0
# disagreement   1.000000  1.000000  1.000000    1.000000       main     val
# inform         0.994924  0.924528  0.958435  424.000000       main     val
# other          0.045455  0.500000  0.083333    2.000000       main     val
# question       0.833333  1.000000  0.909091    5.000000       main     val
# suggest        0.166667  0.500000  0.250000    2.000000       main     val
# accuracy       0.921659  0.921659  0.921659    0.921659       main     val
# macro avg      0.506730  0.654088  0.533477  434.000000       main     val
# weighted avg   0.984882  0.921659  0.950665  434.000000       main     val
#
#               use_pos  use_context  use_trans  use_weights  batch_size  epoch  \
# Unnamed: 0
# disagreement    False        False      False        False           4     13
# inform          False        False      False        False           4     13
# other           False        False      False        False           4     13
# question        False        False      False        False           4     13
# suggest         False        False      False        False           4     13
# accuracy        False        False      False        False           4     13
# macro avg       False        False      False        False           4     13
# weighted avg    False        False      False        False           4     13
#
#               lr_rate  resample_perc  n_classes        timestamp_now
# Unnamed: 0
# disagreement  0.00001           0.05          7  2024-06-24 20:23:58
# inform        0.00001           0.05          7  2024-06-24 20:23:58
# other         0.00001           0.05          7  2024-06-24 20:23:58
# question      0.00001           0.05          7  2024-06-24 20:23:58
# suggest       0.00001           0.05          7  2024-06-24 20:23:58
# accuracy      0.00001           0.05          7  2024-06-24 20:23:58
# macro avg     0.00001           0.05          7  2024-06-24 20:23:58
# weighted avg  0.00001           0.05          7  2024-06-24 20:23:58

# %%
#best_test = best_test.drop(columns=['timestamp_now'])
#best_test = best_test.drop_duplicates()

# %%
best_test[(best_test['use_pos']==True) & (best_test['use_context']==True) & (best_test['use_trans']==True)]
# Out:
#               precision    recall  f1-score     support model_name dataset  \
# Unnamed: 0
# disagreement   1.000000  1.000000  1.000000    1.000000       main     val
# inform         0.990499  0.983491  0.986982  424.000000       main     val
# other          0.000000  0.000000  0.000000    2.000000       main     val
# question       0.625000  1.000000  0.769231    5.000000       main     val
# suggest        0.000000  0.000000  0.000000    2.000000       main     val
# accuracy       0.974654  0.974654  0.974654    0.974654       main     val
# macro avg      0.435916  0.497248  0.459369  434.000000       main     val
# weighted avg   0.977181  0.974654  0.975407  434.000000       main     val
#
#               use_pos  use_context  use_trans  use_weights  batch_size  epoch  \
# Unnamed: 0
# disagreement     True         True       True         True           4     12
# inform           True         True       True         True           4     12
# other            True         True       True         True           4     12
# question         True         True       True         True           4     12
# suggest          True         True       True         True           4     12
# accuracy         True         True       True         True           4     12
# macro avg        True         True       True         True           4     12
# weighted avg     True         True       True         True           4     12
#
#               lr_rate  resample_perc  n_classes        timestamp_now
# Unnamed: 0
# disagreement  0.00005            0.1          7  2024-06-21 13:51:25
# inform        0.00005            0.1          7  2024-06-21 13:51:25
# other         0.00005            0.1          7  2024-06-21 13:51:25
# question      0.00005            0.1          7  2024-06-21 13:51:25
# suggest       0.00005            0.1          7  2024-06-21 13:51:25
# accuracy      0.00005            0.1          7  2024-06-21 13:51:25
# macro avg     0.00005            0.1          7  2024-06-21 13:51:25
# weighted avg  0.00005            0.1          7  2024-06-21 13:51:25

# %%
import matplotlib.pyplot as plt
import numpy as np

classes = (list(best_test[(best_test['use_pos']==False) & (best_test['use_context']==False) & (best_test['use_trans']==False)].index))
perc = {
    'original': list(best_test[(best_test['use_pos']==False) & (best_test['use_context']==False) & (best_test['use_trans']==False)]['f1-score'].round(2)),
    'pos': list(best_test[(best_test['use_pos']==True) & (best_test['use_context']==False) & (best_test['use_trans']==False)]['f1-score'].round(2)),
    'context': list(best_test[(best_test['use_pos']==False) & (best_test['use_context']==True) & (best_test['use_trans']==False)]['f1-score'].round(2)),
    'trans': list(best_test[(best_test['use_pos']==False) & (best_test['use_context']==False) & (best_test['use_trans']==True)]['f1-score'].round(2)),
    'pos_trans': list(best_test[(best_test['use_pos']==True) & (best_test['use_context']==False) & (best_test['use_trans']==True)]['f1-score'].round(2)),
    'pos_context': list(best_test[(best_test['use_pos']==True) & (best_test['use_context']==True) & (best_test['use_trans']==False)]['f1-score'].round(2)),
    'context_trans': list(best_test[(best_test['use_pos']==False) & (best_test['use_context']==True) & (best_test['use_trans']==True)]['f1-score'].round(2)),
    'pos_context_trans': list(best_test[(best_test['use_pos']==True) & (best_test['use_context']==True) & (best_test['use_trans']==True)]['f1-score'].round(2)),
}

x = np.arange(len(classes))  # the label locations
width = 0.1  # the width of the bars
multiplier = 0
fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in perc.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('(%)')
#ax.set_title('Speech act classes f1')
ax.set_xticks(x + width, classes, rotation=90)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 1.2)

plt.show()

# %%
pd.DataFrame(perc, index=[classes]).T
# Out:
#                   disagreement inform other question suggest accuracy  \
# original                  1.00   0.96  0.08     0.91    0.25     0.92
# pos                       0.11   0.94  0.06     0.83    0.50     0.88
# context                   1.00   0.98  0.00     0.67    0.00     0.96
# trans                     0.67   0.97  0.00     0.91    0.00     0.94
# pos_trans                 1.00   0.98  0.15     0.91    0.00     0.97
# pos_context               0.00   0.95  0.06     0.62    0.00     0.91
# context_trans             0.18   0.97  0.00     0.57    0.00     0.94
# pos_context_trans         1.00   0.99  0.00     0.77    0.00     0.97
#
#                   macro avg weighted avg
# original               0.53         0.95
# pos                    0.49         0.93
# context                0.53         0.97
# trans                  0.51         0.96
# pos_trans              0.61         0.97
# pos_context            0.33         0.94
# context_trans          0.35         0.96
# pos_context_trans      0.46         0.98
